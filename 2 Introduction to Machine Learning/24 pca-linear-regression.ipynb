# %% [markdown]
# # PCA and Linear Regression
#
# In this practical, we explore how dimentionality reduction with PCA affects performance when training a linear regression model.

# %% [markdown]
# We use a dataset called mtcars, which comprises of data extracted from the 1974 Motor Trend US magazine, and includes fuel consumption and 10 aspects of automobile design and performance for 32 automobiles (1973–74 models).
#
# <img src="imgs/mtcars.png" width="400">
#
#
# Our aim is to predict horsepower `hp` using following variables as the predictors:
# ```
# mpg
# disp
# drat
# wt
# qsec
# ```

# %% [markdown]
# ### 1. Read Dataset
# Use pandas to read the csv `data/mtcars.csv` and define the input matrix `X` retaining the columns `["mpg", "disp", "drat", "wt", "qsec"]]` and the output `y` with column `"hp"`.

# %%
import numpy as np
import pandas as pd


# your code here...

# %% [markdown]
# ### 2. Test and Train splits
#
# Split your data into `X_train, X_test, y_train, y_test` using sklearn's `train_test_split`. Use a `test_size` of 0.2.

# %%
from sklearn.model_selection import train_test_split

# Your code here ...

# %% [markdown]
# ### 3. Standrdisation
#
# Use the `StandardScaler` to normalise your `X_train` and `X_test` data. Make sure you only fit on `X_train`.
# Call the scaled matrices `X_train_scaled` and `X_test_scaled`.

# %%
from sklearn.preprocessing import StandardScaler

# Your code here ...

# %% [markdown]
# ### 4. Fit a Linear Regression Model
#
# Fit a linear regression model on X_train_scaled and y and compute $R^2$ for the test data.

# %%
from sklearn.linear_model import LinearRegression

# Your code here ...

# %% [markdown]
# ### 5. PCA
#
# Find the principal components of `X_train_scaled` using PCA. Do not set the number of components. In the next step, we will train a lr for various number of retained components and compare performance.
#
# Make sure you only fit on `X_train_scaled`. Apply the PCA transformation on  `X_train_scaled` and `X_test_scaled`. You can call your new variables `X_train_reduced` and `X_test_reduced`.

# %%
from sklearn.decomposition import PCA

# Your code here ...

# %% [markdown]
# ### 6. Number of Components and Performance
#
# Loop over the range of number of components `n` you can have with your input data (1 to 5) and retain up to `n` component at a time. Train a linear regression model on the retained components for your input data and compute $R^2$ on your test data (make sure you retain the same bumber of components in `X_test_reduced` as done with `X_train_reduced`). What can you observe?

# %%
# Your code here ...
