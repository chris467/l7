# %% [markdown]
# # Practical 3 - crosstab, cut, factorize

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/countries.csv', decimal=",")
df.head()

# %% [markdown]
# **Exercise 1**: Create a column called `Income group (amount)`, with `labels=['Low', 'Medium', 'High']`, using `.cut` to indicate which of these three bins of `GDP ($ per capita)` each country falls into. Have a look at the number of countries in each category using `.value_counts()`.

# %% [markdown]
# **Exercise 2**: Create another column with the same 'Low', 'Medium' and 'High' values, except this time use the `.qcut` method to have an equal number of countries in each.

# %% [markdown]
# **Exercise 3**: Use `.groupby` to look at how many countries from each `Region` fall into each category in this new column. Call the new DataFrame `reg_inc`.

# %% [markdown]
# Now if we look at `reg_inc`:

# %%
reg_inc

# %% [markdown]
# We can see that we have a MultiIndex over the index! It might be more easily visible to have this as columns, so we can `unstack` the DataFrame:

# %%
reg_inc.unstack()

# %% [markdown]
# **Exercise 4**: Use `pd.crosstab(col1, col2)` to show, for each `Income group (amount)`, how many countries have `Net inward migration`, and how many do not. You will need to create the `Net inward migration` column as you did in the previous practical.
